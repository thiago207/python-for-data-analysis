# %% [markdown]
# # Trabalhando com eixos

# %% [markdown]
# ## Gráfico de linhas

# %%
import matplotlib.pyplot as plt

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

fig, ax = plt.subplots()

ax.plot(meses, vendas)
ax.set_xlabel('Mês')
ax.set_ylabel('Vendas (em milhares de reais)')
ax.set_title('Crescimento das Vendas ao Longo do Ano')

plt.show()

# %% [markdown]
# ## Gráfico de barras

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

fig, ax = plt.subplots()

ax.bar(produtos, quantidades)
ax.set_xlabel('Produto')
ax.set_ylabel('Quantidade de vendas')
ax.set_title('Quantidade de vendas por produto')

plt.show()

# %% [markdown]
# ## Gráfico de pizza

# %%
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades_vendidas = [45, 30, 15, 10]
destaque = [0.1, 0, 0, 0]  # destacar a primeira fatia

fig, ax = plt.subplots()

ax.pie(quantidades_vendidas, labels=categorias, explode=destaque, autopct='%.1f')
ax.set_title('Categorias de produtos vendidos')

plt.show()

# %% [markdown]
# ## Gráfico de barras empilhadas

# %%
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

fig, ax = plt.subplots()

ax.bar(anos, vendas_online, label='Online')
ax.bar(anos, vendas_loja, bottom=vendas_online, label='Loja')

ax.set_xlabel('Ano')
ax.set_ylabel('Vendas (em milhões de reais)')
ax.set_title('Vendas online vs loja')

ax.set_xticks(anos)

ax.legend()

plt.show()

# %% [markdown]
# ## Mais de um sistema de eixos em uma figura

# %%
import matplotlib.pyplot as plt


fig , axs = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

axs[0].plot(meses, vendas)
    
axs[1].bar(meses, vendas)

plt.show()

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12,10))



#grafico 1 - linha

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

axs[0,0].plot(meses, vendas)
axs[0,0].set_xlabel('Mês')
axs[0,0].set_ylabel('Vendas (em milhares de reais)')
axs[0,0].set_title('Crescimento das Vendas ao Longo do Ano')


#grafico 2 - barras 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

axs[0,1].bar(produtos, quantidades)
axs[0,1].set_xlabel('Produto')
axs[0,1].set_ylabel('Quantidade de vendas')
axs[0,1].set_title('Quantidade de vendas por produto')


#grafico 3 - pizza
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades_vendidas = [45, 30, 15, 10]
destaque = [0.1, 0, 0, 0]  # destacar a primeira fatia

axs[1,0].pie(quantidades_vendidas, labels=categorias, explode=destaque, autopct='%.1f')
axs[1,0].set_title('Categorias de produtos vendidos')


#grafico 4 - barras empilhadas
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]



axs[1,1].bar(anos, vendas_online, label='Online')
axs[1,1].bar(anos, vendas_loja, bottom=vendas_online, label='Loja')

axs[1,1].set_xlabel('Ano')
axs[1,1].set_ylabel('Vendas (em milhões de reais)')
axs[1,1].set_title('Vendas online vs loja')

axs[1,1].set_xticks(anos)

axs[1,1].legend()


#ajustes finais

fig.suptitle('Titulo FIGURA', fontsize=20)
plt.show()

# %% [markdown]
# OUTRA FORMA DE SE REFERIR A POSICAO

# %%
#MOSAICO
import matplotlib.pyplot as plt

mosaico = 'AB;CD'
fig , axs = plt.subplot_mosaic(mosaico, figsize=(12, 10))

plt.show()

# %%
mosaico = 'AB;CD'

fig , axs = plt.subplot_mosaic(mosaico, figsize=(12, 10))



#grafico 1 - linha

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

axs['A'].plot(meses, vendas)
axs['A'].set_xlabel('Mês')
axs['A'].set_ylabel('Vendas (em milhares de reais)')
axs['A'].set_title('Crescimento das Vendas ao Longo do Ano')


#grafico 2 - barras 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

axs['B'].bar(produtos, quantidades)
axs['B'].set_xlabel('Produto')
axs['B'].set_ylabel('Quantidade de vendas')
axs['B'].set_title('Quantidade de vendas por produto')


#grafico 3 - pizza
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades_vendidas = [45, 30, 15, 10]
destaque = [0.1, 0, 0, 0]  # destacar a primeira fatia

axs['C'].pie(quantidades_vendidas, labels=categorias, explode=destaque, autopct='%.1f')
axs['C'].set_title('Categorias de produtos vendidos')


#grafico 4 - barras empilhadas
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]



axs['D'].bar(anos, vendas_online, label='Online')
axs['D'].bar(anos, vendas_loja, bottom=vendas_online, label='Loja')

axs['D'].set_xlabel('Ano')
axs['D'].set_ylabel('Vendas (em milhões de reais)')
axs['D'].set_title('Vendas online vs loja')

axs['D'].set_xticks(anos)

axs['D'].legend()


#ajustes finais

fig.suptitle('Titulo FIGURA', fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt

mosaico = 'AA;BB;CD'
fig , axs = plt.subplot_mosaic(mosaico, figsize=(12, 10))

plt.show()

# %%
mosaico = 'AA;BB;CD'

espacamento = {'wspace' : 0.3, 'hspace' : 0.4}

fig , axs = plt.subplot_mosaic(mosaico, figsize=(12, 10), gridspec_kw=espacamento)


#grafico 1 - linha

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

axs['A'].plot(meses, vendas)
axs['A'].set_xlabel('Mês')
axs['A'].set_ylabel('Vendas (em milhares de reais)')
axs['A'].set_title('Crescimento das Vendas ao Longo do Ano')


#grafico 2 - barras 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

axs['B'].bar(produtos, quantidades)
axs['B'].set_xlabel('Produto')
axs['B'].set_ylabel('Quantidade de vendas')
axs['B'].set_title('Quantidade de vendas por produto')


#grafico 3 - pizza
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades_vendidas = [45, 30, 15, 10]
destaque = [0.1, 0, 0, 0]  # destacar a primeira fatia

axs['C'].pie(quantidades_vendidas, labels=categorias, explode=destaque, autopct='%.1f')
axs['C'].set_title('Categorias de produtos vendidos')


#grafico 4 - barras empilhadas
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]



axs['D'].bar(anos, vendas_online, label='Online')
axs['D'].bar(anos, vendas_loja, bottom=vendas_online, label='Loja')

axs['D'].set_xlabel('Ano')
axs['D'].set_ylabel('Vendas (em milhões de reais)')
axs['D'].set_title('Vendas online vs loja')

axs['D'].set_xticks(anos)

axs['D'].legend()


#ajustes finais

fig.suptitle('Titulo FIGURA', fontsize=20)
plt.show()
