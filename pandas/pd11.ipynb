# %%
import pandas as pd

vendas_df = pd.read_csv(r'C:\Users\Pichau\Documents\estudos\modulos-python\modulos-python\pandas\Contoso - Vendas - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'C:\Users\Pichau\Documents\estudos\modulos-python\modulos-python\pandas\Contoso - Cadastro Produtos.csv', sep=';', encoding='latin1')
lojas_df = pd.read_csv(r'C:\Users\Pichau\Documents\estudos\modulos-python\modulos-python\pandas\Contoso - Lojas.csv', sep=';', encoding='latin1')
clientes_df = pd.read_csv(r'C:\Users\Pichau\Documents\estudos\modulos-python\modulos-python\pandas\Contoso - Clientes.csv', sep=';', encoding='latin1')

clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja','Nome da Loja']]

vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.rename(columns={'E-mail': 'E-mail Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
for i, id_loja in enumerate(vendas_df['ID Loja']):
    if id_loja == 222:
      
        vendas_df.loc[i , 'Quantidade Devolvida'] += 1
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
display(vendas_df.loc[2553 , 'Quantidade Devolvida'])

display(vendas_df[vendas_df['ID Loja'] == 222])
print('TOTAL DE CLIENTES DA LOJA 222:')
display(vendas_df[vendas_df['ID Loja'] == 222] ['ID Cliente'].nunique())

condicao = (vendas_df['ID Loja'] == 222) & (vendas_df['Quantidade Devolvida'] != 3)

vendas_df.loc[condicao, 'Quantidade Devolvida'] -= 1
# Out:
# np.int64(3)
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 2553               2554    02/01/2017    02/01/2017         0      222
# 38921             38922    17/01/2017    17/01/2017         0      222
# 45155             45156    19/01/2017    19/01/2017         0      222
# 51117             51118    22/01/2017    29/01/2017         7      222
# 52480             52481    22/01/2017    22/01/2017         0      222
# ...                 ...           ...           ...       ...      ...
# 979149           979150    31/12/2017    31/12/2017         0      222
# 979160           979161    31/12/2017    31/12/2017         0      222
# 979472           979473    31/12/2017    31/12/2017         0      222
# 980394           980395    31/12/2017    01/01/2018         1      222
# 980595           980596    31/12/2017    31/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...
